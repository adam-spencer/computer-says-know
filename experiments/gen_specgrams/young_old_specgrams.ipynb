# %%
import soundfile as sf
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
longest = ""
longest_size = 0
for file in p.iterdir():
    signal, _ = sf.read(file)
    if signal.size > longest_size:
        longest_size = signal.size
        longest = file.name
print(longest)
# Out:
# digits10.wav

# %%
p = Path('./macrophone_age_comp/tr1576f/')
for i in p.iterdir():
    print(i)
# Out:
# macrophone_age_comp/tr1576f/appwrd11.wav
# macrophone_age_comp/tr1576f/spword38.wav
# macrophone_age_comp/tr1576f/dlramt29.wav
# macrophone_age_comp/tr1576f/nmatad33.wav
# macrophone_age_comp/tr1576f/digits10.wav
# macrophone_age_comp/tr1576f/place14.wav
# macrophone_age_comp/tr1576f/digits13.wav
# macrophone_age_comp/tr1576f/spword15.wav
# macrophone_age_comp/tr1576f/natnum41.wav
# macrophone_age_comp/tr1576f/nmatag24.wav
# macrophone_age_comp/tr1576f/natnum18.wav
# macrophone_age_comp/tr1576f/ATIS40.wav
# macrophone_age_comp/tr1576f/date26.wav
# macrophone_age_comp/tr1576f/natnum16.wav
# macrophone_age_comp/tr1576f/date08.wav
# macrophone_age_comp/tr1576f/appwrd43.wav
# macrophone_age_comp/tr1576f/dlramt23.wav
# macrophone_age_comp/tr1576f/appwrd30.wav
# macrophone_age_comp/tr1576f/fract35.wav
# macrophone_age_comp/tr1576f/TIMIT19.wav
# macrophone_age_comp/tr1576f/dlramt36.wav
# macrophone_age_comp/tr1576f/WSJ22.wav
# macrophone_age_comp/tr1576f/TIMIT27.wav
# macrophone_age_comp/tr1576f/ATIS12.wav
# macrophone_age_comp/tr1576f/TIMIT32.wav
# macrophone_age_comp/tr1576f/place34.wav
# macrophone_age_comp/tr1576f/dlramt25.wav
# macrophone_age_comp/tr1576f/digits31.wav
# macrophone_age_comp/tr1576f/appwrd37.wav
# macrophone_age_comp/tr1576f/appwrd21.wav

# %%
sig1, fs = sf.read('macrophone_age_comp/tr0362f/digits31.wav')
t1 = np.linspace(0,sig1.size / fs, sig1.size)
sig2, _ = sf.read('macrophone_age_comp/tr1576f/digits10.wav')
t2 = np.linspace(0,sig2.size / fs, sig2.size)

# %%
ipd.Audio(sig1, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(sig2, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t1,sig1)

# %%
plt.plot(t2,sig2)

# %%
plt.figure(figsize=(10,10), layout='tight')
plt.subplot(2,1,1)
plt.specgram(sig1, Fs=fs)
plt.title('24 Year Old')
plt.subplot(2,1,2)
plt.specgram(sig2, Fs=fs)
plt.title('83 Year Old')

None
